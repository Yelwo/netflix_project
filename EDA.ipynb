# %%
import pandas as pd

data = pd.read_csv('netflix_titles.csv')
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
data['genres'] = data['listed_in']
data['genres'] = data['genres'].apply(lambda a: [i.strip() for i in a.split(',')])
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description  \
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
#                                                  genres
# 0                                       [Documentaries]
# 1     [International TV Shows, TV Dramas, TV Mysteries]
# 2     [Crime TV Shows, International TV Shows, TV Ac...
# 3                              [Docuseries, Reality TV]
# 4     [International TV Shows, Romantic TV Shows, TV...
# ...                                                 ...
# 8802                   [Cult Movies, Dramas, Thrillers]
# 8803           [Kids' TV, Korean TV Shows, TV Comedies]
# 8804                          [Comedies, Horror Movies]
# 8805               [Children & Family Movies, Comedies]
# 8806   [Dramas, International Movies, Music & Musicals]
#
# [8807 rows x 13 columns]

# %%
data = data[['title', 'genres', 'type']]
[movie[1] for movie in data.values]
# Out:
# [['Documentaries'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Action & Adventure'],
#  ['Docuseries', 'Reality TV'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['TV Dramas', 'TV Horror', 'TV Mysteries'],
#  ['Children & Family Movies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['British TV Shows', 'Reality TV'],
#  ['Comedies', 'Dramas'],
#  ['Crime TV Shows', 'Docuseries', 'International TV Shows'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Action & Adventure'],
#  ['Dramas', 'International Movies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['British TV Shows', 'Crime TV Shows', 'Docuseries'],
#  ['TV Comedies', 'TV Dramas'],
#  ['Documentaries', 'International Movies'],
#  ['Crime TV Shows', 'Spanish-Language TV Shows', 'TV Dramas'],
#  ['Thrillers'],
#  ['International TV Shows',
#   'Spanish-Language TV Shows',
#   'TV Action & Adventure'],
#  ['Crime TV Shows', 'Docuseries', 'International TV Shows'],
#  ['International TV Shows', 'TV Action & Adventure', 'TV Dramas'],
#  ['Comedies', 'International Movies'],
#  ['Children & Family Movies'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Docuseries', 'International TV Shows', 'Reality TV'],
#  ['Comedies', 'International Movies', 'Music & Musicals'],
#  ['Comedies'],
#  ['Horror Movies', 'Sci-Fi & Fantasy'],
#  ['Thrillers'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['TV Comedies'],
#  ['British TV Shows', 'International TV Shows', 'TV Comedies'],
#  ['International TV Shows', 'TV Dramas', 'TV Thrillers'],
#  ["Kids' TV"],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Action & Adventure', 'Dramas'],
#  ["Kids' TV"],
#  ["Kids' TV", 'TV Sci-Fi & Fantasy'],
#  ['Action & Adventure', 'Classic Movies', 'Dramas'],
#  ['Dramas', 'Horror Movies', 'Thrillers'],
#  ['Action & Adventure', 'Horror Movies', 'Thrillers'],
#  ['Action & Adventure', 'Horror Movies', 'Thrillers'],
#  ['Documentaries'],
#  ['Action & Adventure'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Dramas', 'Thrillers'],
#  ['International TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'TV Dramas', 'TV Sci-Fi & Fantasy'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Reality TV'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Children & Family Movies'],
#  ["Kids' TV"],
#  ['Docuseries', 'International TV Shows'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Documentaries', 'International Movies', 'Sports Movies'],
#  ['International TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'Reality TV', 'Romantic TV Shows'],
#  ['Children & Family Movies'],
#  ['British TV Shows', 'Docuseries', 'International TV Shows'],
#  ['Dramas', 'International Movies'],
#  ['Reality TV'],
#  ['Children & Family Movies'],
#  ['Anime Series', 'International TV Shows'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Children & Family Movies'],
#  ['Action & Adventure'],
#  ['Crime TV Shows', 'TV Comedies', 'TV Dramas'],
#  ['Reality TV'],
#  ['Action & Adventure', 'Comedies', 'Dramas'],
#  ['Anime Series', "Kids' TV"],
#  ['International Movies', 'Thrillers'],
#  ["Kids' TV", 'Korean TV Shows'],
#  ['Documentaries', 'Sports Movies'],
#  ["Kids' TV"],
#  ['Sci-Fi & Fantasy', 'Thrillers'],
#  ['Documentaries', 'International Movies'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Reality TV'],
#  ['Documentaries', 'Music & Musicals'],
#  ["Kids' TV", 'TV Comedies', 'TV Sci-Fi & Fantasy'],
#  ['British TV Shows', "Kids' TV"],
#  ['TV Comedies', 'TV Dramas'],
#  ["Kids' TV"],
#  ['Documentaries', 'Sports Movies'],
#  ['Docuseries', 'Science & Nature TV'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ["Kids' TV", 'Korean TV Shows'],
#  ['Action & Adventure', 'Comedies', 'Dramas'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Children & Family Movies', 'Dramas'],
#  ["Kids' TV", 'TV Dramas', 'Teen TV Shows'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['Docuseries', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ["Kids' TV"],
#  ['Dramas'],
#  ['Comedies', 'Romantic Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Dramas', 'Romantic Movies'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Documentaries'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Thrillers'],
#  ["Kids' TV"],
#  ["Kids' TV", 'Korean TV Shows'],
#  ['Crime TV Shows', 'TV Action & Adventure', 'TV Comedies'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Dramas'],
#  ['Children & Family Movies', 'Music & Musicals'],
#  ['Action & Adventure', 'Classic Movies', 'Cult Movies'],
#  ['International TV Shows', 'TV Action & Adventure', 'TV Comedies'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Action & Adventure', 'Dramas'],
#  ['Action & Adventure'],
#  ['Dramas', 'Romantic Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Classic Movies', 'Comedies', 'Dramas'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Action & Adventure'],
#  ['Dramas'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Comedies', 'Cult Movies'],
#  ['Comedies', 'Cult Movies', 'Music & Musicals'],
#  ['Comedies', 'Music & Musicals'],
#  ['Reality TV'],
#  ['TV Shows'],
#  ['Action & Adventure', 'Comedies'],
#  ['Thrillers'],
#  ['Action & Adventure', 'International Movies'],
#  ['Comedies'],
#  ["Kids' TV"],
#  ['Anime Series', 'International TV Shows', 'Teen TV Shows'],
#  ['Action & Adventure', 'Children & Family Movies', 'Cult Movies'],
#  ['Comedies', 'Dramas', 'Romantic Movies'],
#  ['Sci-Fi & Fantasy', 'Thrillers'],
#  ['Comedies', 'Romantic Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['TV Comedies'],
#  ['Comedies', 'Cult Movies', 'Sci-Fi & Fantasy'],
#  ['Dramas'],
#  ['Comedies', 'Romantic Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['Classic Movies', 'Dramas'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Action & Adventure', 'Children & Family Movies', 'Comedies'],
#  ['Action & Adventure', 'Dramas'],
#  ['Documentaries', 'Music & Musicals'],
#  ['Dramas', 'Faith & Spirituality'],
#  ['Comedies', 'Music & Musicals'],
#  ['Documentaries', 'LGBTQ Movies'],
#  ['Action & Adventure', 'Dramas'],
#  ['Dramas', 'Romantic Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Action & Adventure', 'Classic Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Comedies', 'Romantic Movies'],
#  ['Comedies', 'Romantic Movies'],
#  ['Docuseries'],
#  ['Comedies'],
#  ['Action & Adventure', 'Classic Movies'],
#  ['Reality TV'],
#  ['Documentaries', 'Sports Movies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['International TV Shows', 'TV Comedies'],
#  ['Comedies', 'International Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Dramas', 'International Movies'],
#  ['Dramas', 'Independent Movies'],
#  ['Action & Adventure', 'Comedies', 'International Movies'],
#  ['International TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Dramas'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Comedies', 'Romantic Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Action & Adventure', 'Horror Movies', 'International Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Comedies', 'International Movies', 'Music & Musicals'],
#  ['Comedies', 'International Movies'],
#  ['Comedies', 'International Movies'],
#  ['Comedies', 'International Movies', 'Sci-Fi & Fantasy'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Action & Adventure', 'International Movies', 'Music & Musicals'],
#  ['Dramas', 'International Movies', 'Music & Musicals'],
#  ['Dramas', 'International Movies', 'Music & Musicals'],
#  ['Horror Movies', 'International Movies'],
#  ['Horror Movies', 'International Movies'],
#  ['International TV Shows', 'TV Dramas'],
#  ['Docuseries', 'International TV Shows'],
#  ['Action & Adventure', 'International Movies'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Reality TV', 'Teen TV Shows'],
#  ['Anime Series', 'International TV Shows'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Documentaries'],
#  ['Crime TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Crime TV Shows', 'Docuseries', 'International TV Shows'],
#  ['International TV Shows', 'Reality TV'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['International TV Shows', 'TV Comedies', 'TV Dramas'],
#  ['Dramas', 'Independent Movies', 'Romantic Movies'],
#  ['Action & Adventure'],
#  ['Horror Movies'],
#  ['Documentaries', 'Sports Movies'],
#  ['Children & Family Movies', 'Dramas'],
#  ['Reality TV'],
#  ['Documentaries', 'Music & Musicals'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Documentaries', 'LGBTQ Movies', 'Sports Movies'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['Action & Adventure', 'Anime Features'],
#  ['TV Dramas', 'TV Mysteries', 'TV Sci-Fi & Fantasy'],
#  ['International TV Shows', 'TV Comedies'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Comedies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Docuseries', 'International TV Shows'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Action & Adventure', 'Dramas'],
#  ['TV Comedies', 'TV Dramas'],
#  ['Children & Family Movies', 'Comedies', 'Music & Musicals'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Dramas', 'Independent Movies', 'Romantic Movies'],
#  ['International Movies', 'Thrillers'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ["Kids' TV"],
#  ['Documentaries', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Documentaries', 'LGBTQ Movies', 'Sports Movies'],
#  ["Kids' TV"],
#  ['Comedies', 'Independent Movies'],
#  ['Anime Series', 'International TV Shows', 'Romantic TV Shows'],
#  ['Docuseries', 'International TV Shows'],
#  ['Classic Movies', 'Dramas', 'Independent Movies'],
#  ['Dramas', 'International Movies'],
#  ["Kids' TV"],
#  ['Action & Adventure'],
#  ['TV Dramas', 'TV Horror', 'TV Mysteries'],
#  ["Kids' TV"],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['TV Comedies', 'TV Dramas'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['International TV Shows', 'Romantic TV Shows', 'Spanish-Language TV Shows'],
#  ['International TV Shows', 'TV Dramas', 'Teen TV Shows'],
#  ['Stand-Up Comedy'],
#  ['Action & Adventure', 'Anime Features', 'Children & Family Movies'],
#  ['Reality TV'],
#  ['Comedies', 'International Movies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Documentaries', 'International Movies'],
#  ['Comedies', 'Romantic Movies'],
#  ['Dramas', 'International Movies'],
#  ["Kids' TV"],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ['Documentaries', 'Sports Movies'],
#  ['Anime Series', 'International TV Shows'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['International Movies', 'Music & Musicals'],
#  ['Action & Adventure', 'Comedies'],
#  ['TV Action & Adventure', 'TV Dramas', 'TV Mysteries'],
#  ['TV Shows'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Horror Movies', 'Independent Movies', 'International Movies'],
#  ['Children & Family Movies', 'Music & Musicals'],
#  ['Action & Adventure', 'Comedies', 'International Movies'],
#  ['Documentaries', 'International Movies'],
#  ['Comedies', 'Cult Movies', 'International Movies'],
#  ['Documentaries'],
#  ['Classic Movies', 'Dramas', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Horror Movies'],
#  ['Movies'],
#  ['Reality TV'],
#  ['Crime TV Shows', 'Docuseries'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Dramas'],
#  ['Reality TV'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ['Dramas', 'Independent Movies', 'Romantic Movies'],
#  ['Dramas', 'International Movies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Documentaries', 'LGBTQ Movies'],
#  ['Documentaries', 'International Movies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Docuseries'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['TV Comedies'],
#  ["Kids' TV"],
#  ['Children & Family Movies', 'Comedies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Action & Adventure'],
#  ['Dramas'],
#  ['Children & Family Movies', 'Comedies', 'Sci-Fi & Fantasy'],
#  ['Anime Series', 'International TV Shows', 'TV Thrillers'],
#  ['Action & Adventure', 'Horror Movies', 'Sci-Fi & Fantasy'],
#  ['Classic Movies', 'Comedies', 'Cult Movies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Dramas', 'Thrillers'],
#  ['TV Dramas', 'Teen TV Shows'],
#  ['Comedies', 'Romantic Movies'],
#  ['Anime Series', 'International TV Shows'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy', 'Thrillers'],
#  ['Dramas', 'Independent Movies'],
#  ['Comedies'],
#  ['Dramas'],
#  ['Children & Family Movies', 'Comedies', 'Dramas'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Children & Family Movies', 'Comedies', 'Sci-Fi & Fantasy'],
#  ['Comedies'],
#  ['Dramas', 'Sports Movies'],
#  ['Action & Adventure', 'Dramas', 'Sci-Fi & Fantasy'],
#  ['Action & Adventure', 'Comedies', 'Cult Movies'],
#  ['Comedies', 'Dramas'],
#  ['Horror Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Dramas', 'Thrillers'],
#  ['Action & Adventure'],
#  ['Dramas', 'Independent Movies', 'Thrillers'],
#  ['Thrillers'],
#  ['Stand-Up Comedy'],
#  ['Comedies', 'Romantic Movies'],
#  ['TV Dramas', 'TV Sci-Fi & Fantasy'],
#  ['Dramas', 'International Movies'],
#  ['Action & Adventure', 'International Movies', 'Thrillers'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['British TV Shows', 'International TV Shows', 'Reality TV'],
#  ['Documentaries', 'International Movies'],
#  ['International TV Shows', 'Reality TV'],
#  ['British TV Shows', 'Crime TV Shows', 'Docuseries'],
#  ['TV Action & Adventure', 'TV Dramas', 'Teen TV Shows'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Action & Adventure', 'International Movies'],
#  ['Action & Adventure', 'Comedies', 'International Movies'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Comedies', 'Romantic Movies'],
#  ['Anime Series'],
#  ['Action & Adventure', 'International Movies'],
#  ['Documentaries'],
#  ['Reality TV'],
#  ['Crime TV Shows', 'TV Action & Adventure', 'TV Sci-Fi & Fantasy'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['TV Dramas', 'Teen TV Shows'],
#  ['Action & Adventure', 'International Movies'],
#  ['Thrillers'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Comedies'],
#  ["Kids' TV"],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Stand-Up Comedy & Talk Shows', 'TV Comedies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Classic & Cult TV', 'TV Action & Adventure', 'TV Dramas'],
#  ['International TV Shows', 'TV Action & Adventure', 'TV Dramas'],
#  ['Action & Adventure', 'Dramas'],
#  ['Children & Family Movies', 'Sports Movies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Comedies', 'International Movies'],
#  ['Action & Adventure', 'Horror Movies', 'International Movies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['TV Action & Adventure', 'TV Sci-Fi & Fantasy'],
#  ['Anime Series', 'Stand-Up Comedy & Talk Shows'],
#  ['International TV Shows',
#   'Spanish-Language TV Shows',
#   'TV Action & Adventure'],
#  ['Dramas', 'Romantic Movies'],
#  ['Docuseries'],
#  ['Documentaries'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies', 'Sports Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['Children & Family Movies'],
#  ['TV Dramas'],
#  ['Dramas'],
#  ['Comedies', 'International Movies'],
#  ['Anime Features', 'Children & Family Movies', 'International Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['British TV Shows', 'International TV Shows', 'Reality TV'],
#  ['International TV Shows', 'Reality TV', 'Romantic TV Shows'],
#  ['Children & Family Movies'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Classic & Cult TV', 'Crime TV Shows', 'International TV Shows'],
#  ['Crime TV Shows', 'International TV Shows', 'Romantic TV Shows'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Action & Adventure'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Docuseries', 'Science & Nature TV'],
#  ['Horror Movies', 'LGBTQ Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Comedies', 'International Movies'],
#  ['Docuseries'],
#  ['Dramas', 'Independent Movies', 'Thrillers'],
#  ['Dramas'],
#  ['Dramas', 'Romantic Movies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Action & Adventure', 'Dramas', 'Romantic Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Anime Series', 'International TV Shows'],
#  ['Comedies', 'Cult Movies'],
#  ['Documentaries', 'International Movies', 'Music & Musicals'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Documentaries', 'International Movies', 'Sports Movies'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['TV Comedies', 'TV Dramas', 'Teen TV Shows'],
#  ['Children & Family Movies', 'Comedies', 'Sports Movies'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Documentaries'],
#  ['Horror Movies', 'International Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Crime TV Shows', 'Docuseries'],
#  ['Reality TV'],
#  ['Documentaries', 'International Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Dramas', 'Independent Movies'],
#  ['Movies'],
#  ['Children & Family Movies', 'Dramas', 'International Movies'],
#  ["Kids' TV"],
#  ['Documentaries', 'Sports Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Stand-Up Comedy'],
#  ['Comedies', 'Documentaries', 'International Movies'],
#  ['TV Comedies', 'TV Dramas', 'Teen TV Shows'],
#  ['International TV Shows', 'TV Dramas', 'TV Sci-Fi & Fantasy'],
#  ['Horror Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ['Docuseries'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Stand-Up Comedy'],
#  ['Thrillers'],
#  ['Children & Family Movies', 'Comedies', 'Sci-Fi & Fantasy'],
#  ['International TV Shows', 'Romantic TV Shows', 'Spanish-Language TV Shows'],
#  ['Romantic TV Shows', 'TV Dramas'],
#  ['Comedies', 'International Movies'],
#  ['Crime TV Shows', 'Docuseries', 'International TV Shows'],
#  ['Comedies', 'Dramas', 'Romantic Movies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Anime Series', 'TV Horror', 'TV Thrillers'],
#  ['Comedies', 'Music & Musicals'],
#  ['Documentaries', 'International Movies'],
#  ['Action & Adventure', 'International Movies'],
#  ['Docuseries'],
#  ['Dramas', 'International Movies'],
#  ['Docuseries'],
#  ['Action & Adventure', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Comedies'],
#  ['Dramas', 'International Movies'],
#  ['International Movies', 'Romantic Movies'],
#  ['Comedies', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ["Kids' TV"],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Stand-Up Comedy & Talk Shows', 'TV Comedies'],
#  ["Kids' TV"],
#  ['TV Action & Adventure', 'TV Dramas', 'TV Sci-Fi & Fantasy'],
#  ['British TV Shows', 'International TV Shows', 'TV Comedies'],
#  ['British TV Shows', 'International TV Shows', 'TV Comedies'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Dramas', 'International Movies'],
#  ['British TV Shows', 'Crime TV Shows', 'Docuseries'],
#  ['TV Comedies'],
#  ['International TV Shows', 'TV Comedies'],
#  ["Kids' TV", 'Korean TV Shows', 'TV Comedies'],
#  ['British TV Shows', 'Crime TV Shows', 'International TV Shows'],
#  ['International TV Shows', 'TV Dramas'],
#  ["Kids' TV"],
#  ['TV Comedies', 'TV Dramas'],
#  ["Kids' TV"],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Dramas', 'International Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Dramas', 'International Movies'],
#  ['Crime TV Shows', 'TV Horror', 'TV Mysteries'],
#  ['International TV Shows', 'TV Dramas'],
#  ['Dramas', 'International Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Docuseries', 'International TV Shows', 'Science & Nature TV'],
#  ['International TV Shows', 'Reality TV'],
#  ['British TV Shows', 'International TV Shows', 'TV Dramas'],
#  ["Kids' TV", 'TV Action & Adventure', 'TV Sci-Fi & Fantasy'],
#  ['British TV Shows', "Kids' TV"],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Action & Adventure'],
#  ['International TV Shows', 'TV Comedies'],
#  ["Kids' TV", 'Korean TV Shows'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ["Kids' TV"],
#  ['Romantic TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'Reality TV'],
#  ['Horror Movies', 'LGBTQ Movies'],
#  ['International Movies', 'Romantic Movies', 'Thrillers'],
#  ['Comedies', 'International Movies'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Action & Adventure', 'Cult Movies', 'International Movies'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['Horror Movies', 'Sci-Fi & Fantasy'],
#  ['Action & Adventure'],
#  ['Action & Adventure'],
#  ['Documentaries', 'Sports Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Comedies'],
#  ['Action & Adventure', 'Comedies', 'Sci-Fi & Fantasy'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['International TV Shows', "Kids' TV", 'TV Mysteries'],
#  ['Action & Adventure', 'Comedies'],
#  ['Action & Adventure', 'Thrillers'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Action & Adventure', 'International Movies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Comedies', 'Dramas', 'Romantic Movies'],
#  ['Dramas', 'Faith & Spirituality', 'International Movies'],
#  ['International TV Shows', 'TV Comedies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Action & Adventure', 'Classic Movies', 'Comedies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Comedies', 'Dramas'],
#  ['Comedies', 'Romantic Movies'],
#  ['Comedies'],
#  ['Dramas', 'Romantic Movies'],
#  ['Horror Movies'],
#  ['International TV Shows', 'TV Comedies', 'TV Dramas'],
#  ["Kids' TV"],
#  ['Dramas', 'International Movies'],
#  ['Anime Series', "Kids' TV"],
#  ['Dramas', 'Romantic Movies'],
#  ['Comedies', 'Romantic Movies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Action & Adventure', 'Comedies', 'Sports Movies'],
#  ['Dramas', 'Thrillers'],
#  ['Dramas'],
#  ['Thrillers'],
#  ['Action & Adventure', 'Children & Family Movies', 'Classic Movies'],
#  ['Action & Adventure', 'Children & Family Movies', 'Dramas'],
#  ['Children & Family Movies', 'Dramas'],
#  ['Dramas'],
#  ['Action & Adventure'],
#  ['Dramas', 'International Movies'],
#  ['Horror Movies', 'Thrillers'],
#  ['Action & Adventure'],
#  ['Action & Adventure', 'Romantic Movies'],
#  ['Action & Adventure', 'Horror Movies', 'Sci-Fi & Fantasy'],
#  ['Action & Adventure', 'Horror Movies', 'Sci-Fi & Fantasy'],
#  ['Action & Adventure', 'Horror Movies', 'Sci-Fi & Fantasy'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Dramas', 'Romantic Movies', 'Sci-Fi & Fantasy'],
#  ['Dramas', 'Music & Musicals', 'Romantic Movies'],
#  ['Dramas'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ['Action & Adventure', 'Comedies'],
#  ['Dramas', 'International Movies'],
#  ['Reality TV'],
#  ['Anime Series', 'Crime TV Shows', 'International TV Shows'],
#  ['Thrillers'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['British TV Shows', 'Crime TV Shows', 'Docuseries'],
#  ['Anime Series', 'International TV Shows', 'Teen TV Shows'],
#  ["Kids' TV"],
#  ['Dramas', 'International Movies'],
#  ['Dramas'],
#  ['Anime Series', 'International TV Shows'],
#  ['Comedies', 'International Movies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Documentaries', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Action & Adventure'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Romantic TV Shows', 'TV Dramas'],
#  ['Anime Series', 'International TV Shows'],
#  ['International TV Shows', 'TV Dramas'],
#  ['Documentaries', 'Sports Movies'],
#  ['International TV Shows', 'TV Dramas'],
#  ['Horror Movies'],
#  ['Comedies', 'Romantic Movies'],
#  ['Documentaries', 'International Movies'],
#  ['Comedies', 'International Movies', 'Music & Musicals'],
#  ['International TV Shows', 'Reality TV'],
#  ['Reality TV', 'Romantic TV Shows'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Dramas', 'International Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Docuseries', 'International TV Shows'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['International Movies', 'Music & Musicals', 'Romantic Movies'],
#  ['Reality TV', 'TV Action & Adventure', 'TV Mysteries'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ['TV Action & Adventure', 'TV Dramas', 'TV Sci-Fi & Fantasy'],
#  ['International TV Shows', 'TV Comedies', 'TV Dramas'],
#  ['TV Comedies'],
#  ['International TV Shows', 'TV Dramas'],
#  ["Kids' TV"],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['TV Comedies', 'TV Dramas', 'Teen TV Shows'],
#  ['Crime TV Shows', 'TV Dramas'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['Action & Adventure', 'Anime Features', 'International Movies'],
#  ['International TV Shows', 'Reality TV', 'Spanish-Language TV Shows'],
#  ['TV Dramas'],
#  ['International TV Shows', 'Reality TV', 'Romantic TV Shows'],
#  ['Crime TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['TV Comedies'],
#  ['Crime TV Shows', 'TV Dramas', 'TV Thrillers'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['Docuseries'],
#  ['British TV Shows', 'Docuseries'],
#  ['International TV Shows', 'TV Comedies'],
#  ['Dramas', 'International Movies'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['Dramas'],
#  ['International TV Shows', 'Korean TV Shows', 'TV Comedies'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Action & Adventure', 'Anime Features', 'Classic Movies'],
#  ['Action & Adventure', 'International Movies'],
#  ['International TV Shows', 'TV Comedies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Dramas', 'International Movies'],
#  ['TV Action & Adventure', 'TV Dramas', 'TV Horror'],
#  ['International TV Shows', 'Romantic TV Shows', 'Spanish-Language TV Shows'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Anime Series', 'International TV Shows'],
#  ['Dramas'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Documentaries', 'International Movies', 'Sports Movies'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Dramas'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Dramas', 'Independent Movies'],
#  ['International TV Shows', 'Romantic TV Shows', 'Spanish-Language TV Shows'],
#  ['Docuseries', 'Science & Nature TV'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Thrillers'],
#  ['International TV Shows', 'Romantic TV Shows', 'Spanish-Language TV Shows'],
#  ['Documentaries'],
#  ['Documentaries'],
#  ['Comedies', 'Independent Movies'],
#  ["Kids' TV"],
#  ["Kids' TV"],
#  ['Action & Adventure'],
#  ['Documentaries'],
#  ['Reality TV'],
#  ['Documentaries'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Dramas'],
#  ['TV Shows'],
#  ['Documentaries'],
#  ['Horror Movies'],
#  ['Movies'],
#  ['Movies'],
#  ['International TV Shows', 'TV Dramas'],
#  ['Movies'],
#  ["Kids' TV"],
#  ['Crime TV Shows', 'International TV Shows', 'TV Action & Adventure'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Children & Family Movies', 'Dramas', 'International Movies'],
#  ['Anime Series', 'Crime TV Shows', 'TV Horror'],
#  ['Anime Features', 'Documentaries'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Comedies', 'Horror Movies'],
#  ['Dramas', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Dramas', 'Independent Movies', 'Romantic Movies'],
#  ['International TV Shows',
#   'Spanish-Language TV Shows',
#   'Stand-Up Comedy & Talk Shows'],
#  ['International Movies', 'Thrillers'],
#  ['Dramas', 'Thrillers'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Reality TV'],
#  ['Crime TV Shows', 'TV Action & Adventure', 'TV Comedies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Action & Adventure', 'Comedies', 'Sci-Fi & Fantasy'],
#  ['International TV Shows', 'Romantic TV Shows', 'Spanish-Language TV Shows'],
#  ['Dramas', 'Independent Movies'],
#  ['Children & Family Movies', 'Documentaries', 'International Movies'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Documentaries'],
#  ['Romantic TV Shows', 'TV Comedies', 'TV Dramas'],
#  ['Movies'],
#  ['Movies'],
#  ['Docuseries', 'Science & Nature TV'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['TV Action & Adventure', 'TV Dramas', 'TV Sci-Fi & Fantasy'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Action & Adventure', 'International Movies'],
#  ['Stand-Up Comedy'],
#  ['International TV Shows', 'TV Comedies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Documentaries', 'International Movies'],
#  ['Documentaries', 'International Movies', 'Music & Musicals'],
#  ['TV Shows'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Dramas'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Dramas', 'Faith & Spirituality', 'Romantic Movies'],
#  ['Dramas', 'Independent Movies', 'LGBTQ Movies'],
#  ['Action & Adventure'],
#  ['Comedies', 'Independent Movies', 'LGBTQ Movies'],
#  ['Anime Series', 'International TV Shows'],
#  ['Action & Adventure', 'Cult Movies', 'Sci-Fi & Fantasy'],
#  ["Kids' TV"],
#  ['Documentaries'],
#  ['Dramas', 'Romantic Movies'],
#  ['Comedies', 'International Movies', 'Music & Musicals'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ["Kids' TV"],
#  ['Action & Adventure', 'Dramas'],
#  ['Action & Adventure'],
#  ['Thrillers'],
#  ['British TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['Documentaries'],
#  ['Action & Adventure', 'Dramas'],
#  ['Comedies', 'Dramas', 'Romantic Movies'],
#  ['Comedies', 'Romantic Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['TV Comedies'],
#  ['Cult Movies', 'Horror Movies'],
#  ['Dramas'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Dramas', 'Sports Movies'],
#  ['Dramas', 'Independent Movies', 'LGBTQ Movies'],
#  ['Action & Adventure', 'Dramas', 'Sports Movies'],
#  ['Action & Adventure'],
#  ['Anime Series', 'Romantic TV Shows', 'Teen TV Shows'],
#  ['Horror Movies', 'Thrillers'],
#  ['International TV Shows', 'TV Comedies', 'TV Dramas'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ['Action & Adventure'],
#  ['Action & Adventure', 'Comedies'],
#  ['Action & Adventure', 'Classic Movies', 'Cult Movies'],
#  ['Children & Family Movies'],
#  ['Action & Adventure'],
#  ["Kids' TV"],
#  ['Comedies', 'Romantic Movies'],
#  ['Dramas', 'International Movies', 'LGBTQ Movies'],
#  ['Thrillers'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Comedies', 'Dramas', 'Romantic Movies'],
#  ['Action & Adventure', 'Classic Movies'],
#  ['International TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Dramas', 'Romantic Movies', 'Thrillers'],
#  ['Horror Movies'],
#  ['Comedies', 'Dramas', 'Independent Movies'],
#  ['Thrillers'],
#  ['Crime TV Shows', 'TV Dramas', 'TV Mysteries'],
#  ['Stand-Up Comedy'],
#  ['Comedies', 'International Movies'],
#  ['Dramas'],
#  ['Children & Family Movies', 'Comedies'],
#  ['TV Comedies', 'TV Dramas'],
#  ['Docuseries', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['International TV Shows', 'TV Action & Adventure', 'TV Dramas'],
#  ['Crime TV Shows', 'International TV Shows', 'TV Dramas'],
#  ['Children & Family Movies', 'Dramas', 'Faith & Spirituality'],
#  ['Anime Series', 'International TV Shows'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['International TV Shows', 'TV Action & Adventure', 'TV Dramas'],
#  ['Stand-Up Comedy'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Dramas', 'International Movies', 'Sports Movies'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ['Docuseries'],
#  ['Anime Series', 'International TV Shows'],
#  ['Documentaries', 'International Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Children & Family Movies', 'Comedies', 'Sci-Fi & Fantasy'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['TV Comedies', 'TV Dramas'],
#  ['International Movies', 'Music & Musicals'],
#  ['Dramas', 'International Movies', 'Music & Musicals'],
#  ['Dramas', 'International Movies', 'Music & Musicals'],
#  ['Dramas', 'International Movies', 'Music & Musicals'],
#  ['Action & Adventure', 'Horror Movies'],
#  ['Documentaries'],
#  ["Kids' TV", 'TV Action & Adventure', 'TV Sci-Fi & Fantasy'],
#  ['Dramas', 'International Movies'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Comedies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Documentaries', 'International Movies', 'LGBTQ Movies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['TV Comedies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Action & Adventure', 'Dramas'],
#  ['Thrillers'],
#  ['Documentaries'],
#  ["Kids' TV"],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['Documentaries'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Dramas', 'Independent Movies', 'Sci-Fi & Fantasy'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ["Kids' TV"],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Docuseries', 'International TV Shows'],
#  ['Comedies', 'Independent Movies', 'International Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['TV Dramas'],
#  ['Reality TV', 'TV Horror', 'TV Thrillers'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Children & Family Movies', 'Comedies'],
#  ['TV Action & Adventure', 'TV Horror', 'TV Sci-Fi & Fantasy'],
#  ['International TV Shows', 'TV Dramas'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['International TV Shows', 'TV Horror', 'TV Sci-Fi & Fantasy'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['Comedies'],
#  ['Dramas', 'Thrillers'],
#  ['Anime Series', 'TV Horror', 'TV Thrillers'],
#  ['Independent Movies', 'International Movies', 'Thrillers'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Documentaries', 'International Movies', 'Music & Musicals'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['TV Comedies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Docuseries'],
#  ['Independent Movies', 'Thrillers'],
#  ['International TV Shows', 'TV Dramas'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Action & Adventure'],
#  ['Action & Adventure', 'Dramas', 'International Movies'],
#  ['Dramas', 'International Movies'],
#  ['Documentaries'],
#  ['TV Action & Adventure', 'TV Sci-Fi & Fantasy'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Dramas'],
#  ["Kids' TV", 'TV Comedies'],
#  ['Comedies'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Documentaries'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ['Action & Adventure'],
#  ['Documentaries', 'Dramas'],
#  ['Reality TV'],
#  ['Crime TV Shows', 'Docuseries'],
#  ['TV Dramas'],
#  ['Crime TV Shows', 'TV Dramas'],
#  ['Dramas', 'Independent Movies', 'Thrillers'],
#  ["Kids' TV"],
#  ['Children & Family Movies', 'Comedies'],
#  ['British TV Shows', "Kids' TV"],
#  ['Action & Adventure', 'Dramas'],
#  ["Kids' TV"],
#  ['Action & Adventure', 'Sports Movies'],
#  ['Action & Adventure', 'Horror Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Comedies'],
#  ['Action & Adventure'],
#  ['Children & Family Movies', 'Dramas'],
#  ['Dramas', 'Independent Movies'],
#  ['Children & Family Movies', 'Comedies'],
#  ["Kids' TV"],
#  ['Children & Family Movies', 'Comedies'],
#  ['Children & Family Movies', 'Comedies', 'Music & Musicals'],
#  ['Children & Family Movies', 'Music & Musicals'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Dramas', 'Thrillers'],
#  ['Action & Adventure', 'Dramas', 'Sports Movies'],
#  ['Action & Adventure'],
#  ['Dramas', 'International Movies'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Dramas', 'Thrillers'],
#  ['Comedies'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Dramas', 'International Movies', 'Sci-Fi & Fantasy'],
#  ['Comedies', 'Romantic Movies'],
#  ['Action & Adventure', 'Comedies'],
#  ['Dramas', 'Thrillers'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Action & Adventure'],
#  ['Comedies', 'Independent Movies', 'Romantic Movies'],
#  ['Reality TV'],
#  ['Dramas', 'International Movies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Crime TV Shows', 'International TV Shows', 'Spanish-Language TV Shows'],
#  ['Children & Family Movies', 'Comedies'],
#  ['Horror Movies'],
#  ['International TV Shows', 'Spanish-Language TV Shows', 'TV Comedies'],
#  ['Horror Movies', 'Thrillers'],
#  ['Anime Series', 'International TV Shows'],
#  ['Comedies', 'International Movies'],
#  ['Docuseries', 'Science & Nature TV'],
#  ['International TV Shows', 'TV Comedies', 'TV Dramas'],
#  ['Dramas'],
#  ['Action & Adventure', 'Sci-Fi & Fantasy'],
#  ['Thrillers'],
#  ['International TV Shows', 'TV Dramas', 'TV Thrillers'],
#  ['Dramas', 'International Movies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['Action & Adventure', 'Comedies', 'Dramas'],
#  ['Comedies', 'International Movies'],
#  ['Comedies', 'International Movies'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Comedies', 'International Movies'],
#  ['Comedies', 'International Movies'],
#  ['Action & Adventure', 'Comedies', 'International Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Documentaries', 'International Movies', 'Music & Musicals'],
#  ['Comedies', 'International Movies'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Comedies', 'International Movies', 'Romantic Movies'],
#  ['Comedies', 'International Movies'],
#  ['International TV Shows', 'Romantic TV Shows', 'TV Comedies'],
#  ['Comedies', 'International Movies'],
#  ['Comedies', 'International Movies'],
#  ['Dramas', 'Independent Movies', 'International Movies'],
#  ['International Movies', 'Music & Musicals'],
#  ['TV Action & Adventure', 'TV Dramas', 'TV Sci-Fi & Fantasy'],
#  ['Dramas', 'International Movies', 'Romantic Movies'],
#  ['Comedies', 'Dramas', 'International Movies'],
#  ['Horror Movies', 'International Movies', 'Thrillers'],
#  ['British TV Shows', 'Docuseries', 'International TV Shows'],
#  ['Documentaries', 'International Movies'],
#  ['Dramas', 'International Movies', 'Thrillers'],
#  ...]

# %%
import requests
movies = [{"title": movie[0], "genres": [{"name": genre} for genre in movie[1]], "type": movie[2]} for movie in data.values]
for movie in movies[:1]:
    response = requests.post('http://127.0.0.1:8000/screen-content/', json=movie)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#
# File /opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File /opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/connection.py:214, in HTTPConnection._new_conn(self)
#     213 except OSError as e:
# --> 214     raise NewConnectionError(
#     215         self, f"Failed to establish a new connection: {e}"
#     216     ) from e
#     218 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x1128b3ce0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=8000): Max retries exceeded with url: /movies/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1128b3ce0>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[13], line 4
#       2 movies = [{"title": movie[0], "genres": [{"name": genre} for genre in movie[1]], "type": movie[2]} for movie in data.values]
#       3 for movie in movies[:1]:
# ----> 4     response = requests.post('http://127.0.0.1:8000/movies/', json=movie)
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/share/virtualenvs/cars-9DE2lInT/lib/python3.12/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=8000): Max retries exceeded with url: /movies/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1128b3ce0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
response.text
# Out:
# '{"id":1,"genres":[{"id":1,"name":"Documentaries"}],"title":"Dick Johnson Is Dead","polymorphic_ctype":9}'

# %%
response.request.body
# Out:
# b'{"title": "Dick Johnson Is Dead", "genres": [{"name": "Documentaries"}]}'
